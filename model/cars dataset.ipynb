# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## dataset old cars

# %%
df1=pd.read_csv('Web Scraping/u_old_cars.csv')

# %%
df1.head(25)
# Out:
#         marque        model  Puissance fiscale Carburant  Année  \
# 0   land-rover        Range               12.0    Diesel   2017
# 1   land-rover        Range               12.0    Diesel   2016
# 2          bmw           X5                8.0    Diesel   2016
# 3   land-rover        Range                8.0    Diesel   2018
# 4     mercedes       Classe                8.0    Diesel   2022
# 5     mercedes       Classe                8.0    Diesel   2019
# 6      hyundai        Santa                9.0    Diesel   2020
# 7     mercedes          Gle               12.0    Diesel   2018
# 8   alfa-romeo      Stelvio                9.0    Diesel   2019
# 9         jeep     Renegade                6.0    Diesel   2022
# 10     renault         Clio                6.0    Diesel   2020
# 11  land-rover        Range                8.0    Diesel   2018
# 12     bentley  Continental               30.0   Essence   2017
# 13  volkswagen      Touareg               12.0    Diesel   2023
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26133 entries, 0 to 26132
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   marque             26133 non-null  object
#  1   model              26133 non-null  object
#  2   Puissance fiscale  24172 non-null  float64
#  3   Carburant          26133 non-null  object
#  4   Année              26133 non-null  int64
#  5   Boite de vitesses  25433 non-null  object
#  6   etat               26133 non-null  int64
#  7   price              26133 non-null  int64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 1.6+ MB

# %% [markdown]
# ## dataset new cars

# %%
df2=pd.read_csv('Web Scraping/u_new_cars.csv')

# %%
df2.head(25)
# Out:
#           marque          model  Puissance fiscale Carburant  Année  \
# 0         abarth            595                8.0   Essence   2020
# 1         abarth            595                8.0   Essence   2020
# 2         abarth  595-cabriolet                8.0   Essence   2020
# 3         abarth  595-cabriolet                8.0   Essence   2020
# 4         abarth  595-cabriolet                8.0   Essence   2020
# 5     alfa-romeo             4c               14.0   Essence   2013
# 6     alfa-romeo             4c               14.0   Essence   2014
# 7     alfa-romeo         giulia                9.0    Diesel   2021
# 8     alfa-romeo         giulia                9.0    Diesel   2021
# 9     alfa-romeo         giulia                9.0   Essence   2022
# 10    alfa-romeo      giulietta                6.0    Diesel   2017
# 11    alfa-romeo      giulietta                6.0    Diesel   2017
# 12    alfa-romeo      giulietta                6.0    Diesel   2017
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1116 entries, 0 to 1115
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   marque             1116 non-null   object
#  1   model              1116 non-null   object
#  2   Puissance fiscale  1015 non-null   float64
#  3   Carburant          1116 non-null   object
#  4   Année              1116 non-null   int64
#  5   Boite de vitesses  1108 non-null   object
#  6   etat               1116 non-null   int64
#  7   price              1116 non-null   object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 69.9+ KB

# %% [markdown]
# ## dataset cars global

# %%
df = pd.concat([df1, df2], ignore_index=True)

# %%
df.head()
# Out:
#        marque   model  Puissance fiscale Carburant  Année Boite de vitesses  \
# 0  land-rover   Range               12.0    Diesel   2017       Automatique
# 1  land-rover   Range               12.0    Diesel   2016       Automatique
# 2         bmw      X5                8.0    Diesel   2016       Automatique
# 3  land-rover   Range                8.0    Diesel   2018       Automatique
# 4    mercedes  Classe                8.0    Diesel   2022       Automatique
#
#    etat   price
# 0     0  490000
# 1     0  355000
# 2     0  260000
# 3     0  310000
# 4     0  820000

# %%
df.to_csv('global_cars.csv', index=False, encoding='utf-8')

# %% [markdown]
# ### data preprocessing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27249 entries, 0 to 27248
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   marque             27249 non-null  object
#  1   model              27249 non-null  object
#  2   Puissance fiscale  25187 non-null  float64
#  3   Carburant          27249 non-null  object
#  4   Année              27249 non-null  int64
#  5   Boite de vitesses  26541 non-null  object
#  6   etat               27249 non-null  int64
#  7   price              27249 non-null  object
# dtypes: float64(1), int64(2), object(5)
# memory usage: 1.7+ MB

# %%
# missing values 
sns.heatmap(df.isnull(),cmap = 'magma',cbar = False)
# Out:
# <AxesSubplot:>

# %%
# % of nan value of each columns  
for i in df.columns:
    null_rate = df[i].isnull().sum() / len(df)*100
    print("{}'s null rate: {}%".format(i, round(null_rate, 2)))
# Out:
# marque's null rate: 0.0%
# model's null rate: 0.0%
# Puissance fiscale's null rate: 7.57%
# Carburant's null rate: 0.0%
# Année's null rate: 0.0%
# Boite de vitesses's null rate: 2.6%
# etat's null rate: 0.0%
# price's null rate: 0.0%

# %%
df['price'] = pd.to_numeric(df['price'], errors='coerce')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27249 entries, 0 to 27248
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   marque             27249 non-null  object
#  1   model              27249 non-null  object
#  2   Puissance fiscale  25187 non-null  float64
#  3   Carburant          27249 non-null  object
#  4   Année              27249 non-null  int64
#  5   Boite de vitesses  26541 non-null  object
#  6   etat               27249 non-null  int64
#  7   price              27154 non-null  float64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 1.7+ MB

# %%
# Remove rows with NaN values
df = df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24564 entries, 0 to 27248
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   marque             24564 non-null  object
#  1   model              24564 non-null  object
#  2   Puissance fiscale  24564 non-null  float64
#  3   Carburant          24564 non-null  object
#  4   Année              24564 non-null  int64
#  5   Boite de vitesses  24564 non-null  object
#  6   etat               24564 non-null  int64
#  7   price              24564 non-null  float64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 1.7+ MB

# %%
# missing values 
sns.heatmap(df.isnull(),cmap = 'magma',cbar = False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Marques visualisation

# %%
df['marque'].unique()
# Out:
# array(['land-rover', 'bmw', 'mercedes', 'hyundai', 'alfa-romeo', 'jeep',
#        'renault', 'bentley', 'volkswagen', 'audi', 'honda', 'nissan',
#        'dacia', 'toyota', 'skoda', 'ford', 'mini', 'peugeot', 'ssangyong',
#        'opel', 'porsche', 'gwm', 'jaguar', 'mazda', 'volvo', 'fiat',
#        'citroen', 'suzuki', 'seat', 'iveco', 'mitsubishi', 'dodge', 'kia',
#        'ds', 'maserati', 'lexus', 'gmc', 'chevrolet', 'smart', 'autre',
#        'dfsk', 'daihatsu', 'isuzu', 'chery', 'hafei', 'rover', 'lada',
#        'hummer', 'cupra', 'lancia', 'mahindra', 'cadillac', 'triumph',
#        'tata', 'lifan', 'infiniti', 'gme', 'daewoo', 'zotye', 'abarth',
#        'great-wall', 'tesla', 'geely', 'gaz', 'chrysler', 'simca',
#        'chana', 'faw', 'byd', 'changhe', 'ferrari', 'foton'], dtype=object)

# %%
# Count the occurrences of each marque
marque_counts = df['marque'].value_counts()

plt.figure(figsize=(15, 6))
# Plot the counts using a bar plot
plt.bar(marque_counts.index, marque_counts.values)
plt.xticks(rotation='vertical')
plt.xlabel('Marque')
plt.ylabel('Count')
plt.title('Count of each Marque')
plt.show()

# %%
marque_counts = df['marque'].value_counts()

# Increase the size of the figure
plt.figure(figsize=(15,12))

# Plot the counts using a horizontal bar plot
bars = plt.barh(marque_counts.index, marque_counts.values)

# Annotate each bar with its count
for bar, count in zip(bars, marque_counts.values):
    plt.text(bar.get_width(), bar.get_y() + bar.get_height() / 2, str(count), ha='left', va='center')

plt.xlabel('Count')
plt.ylabel('Marque')
plt.title('Count of each Marque')
plt.show()

# %%
from matplotlib.ticker import FuncFormatter
# Group by 'marque' and calculate the mean price for each group
mean_prices = df.groupby('marque')['price'].mean()
plt.figure(figsize=(15, 6))
# Plot the counts using a bar plot
plt.bar(mean_prices.index, mean_prices.values)
plt.xticks(rotation='vertical')# Plot the mean prices using a bar graph
plt.xlabel('Marque')
plt.ylabel('Mean Price')
plt.title('Mean Price for Each Marque')
plt.gca().get_yaxis().set_major_formatter(FuncFormatter(lambda x, _: int(x)))
plt.show()

# %%
# Exclude 'ferrari' from the DataFrame
df_excluding_ferrari = df[df['marque'] != 'ferrari']

# Group by 'marque' and calculate the mean price for each group
mean_prices = df_excluding_ferrari.groupby('marque')['price'].mean()
plt.figure(figsize=(15, 6))
# Plot the counts using a bar plot
plt.bar(mean_prices.index, mean_prices.values)
plt.xticks(rotation='vertical')# Plot the mean prices using a bar graph
plt.xlabel('Marque')
plt.ylabel('Mean Price')
plt.title('Mean Price for Each Marque')
plt.gca().get_yaxis().set_major_formatter(FuncFormatter(lambda x, _: int(x)))
plt.show()

# %%
import json
marque_price_dict = dict(zip(mean_prices.index, mean_prices.values))

json_file_path = 'marque_price_dict.json'

# Save the dictionary to a JSON file
with open(json_file_path, 'w') as json_file:
    json.dump(marque_price_dict, json_file)

print(f"The dictionary has been successfully saved to {json_file_path}.")
# Out:
# The dictionary has been successfully saved to marque_price_dict.json.

# %%
marque_price_dict
# Out:
# {'abarth': 205894.77777777778,
#  'alfa-romeo': 173196.4757709251,
#  'audi': 298662.1974206349,
#  'autre': 250000.0,
#  'bentley': 800000.0,
#  'bmw': 292582.5388994307,
#  'byd': 50000.0,
#  'cadillac': 826666.6666666666,
#  'chana': 37250.0,
#  'changhe': 27500.0,
#  'chery': 90780.48780487805,
#  'chevrolet': 92900.70921985815,
#  'chrysler': 184250.0,
#  'citroen': 99915.15463917526,
#  'cupra': 436666.6666666667,
#  'dacia': 103346.18175765646,
#  'daewoo': 30125.0,
#  'daihatsu': 45671.875,
#  'dfsk': 131516.12903225806,
#  'dodge': 131562.375,
#  'ds': 240978.0,
#  'faw': 46666.666666666664,
#  'ferrari': 3900000.0,
#  'fiat': 100327.95750708216,
#  'ford': 130968.8793939394,
#  'foton': 50000.0,
#  'gaz': 205000.0,
#  'geely': 267700.0,
#  'gmc': 923333.3333333334,
#  'gme': 40000.0,
#  'great-wall': 69000.0,
#  'gwm': 470000.0,
#  'hafei': 49200.0,
#  'honda': 87456.98511166254,
#  'hummer': 195000.0,
#  'hyundai': 156206.64280442803,
#  'infiniti': 80000.0,
# ...

# %% [markdown]
# ### Boite de vitesses visualisation

# %%
df['Boite de vitesses'].unique()
# Out:
# array(['Automatique', 'Manuelle'], dtype=object)

# %%
# Count the occurrences of each 'Boite de vitesses'
boite_counts = df['Boite de vitesses'].value_counts()

# Plot the counts using a pie chart
plt.pie(boite_counts, labels=boite_counts.index, autopct='%1.1f%%', startangle=90)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Distribution of Boite de vitesses')
plt.show()

# %% [markdown]
# ### Carburant visualisation

# %%
df['Carburant'].unique()
# Out:
# array(['Diesel', 'Essence', 'Hybride', 'Electrique'], dtype=object)

# %%
# Count the occurrences of each 'Carburant'
boite_counts = df['Carburant'].value_counts()

# Plot the counts using a pie chart
plt.pie(boite_counts, labels=boite_counts.index, autopct='%1.1f%%', startangle=90)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Distribution of Carburant')
plt.show()

# %%
# Count the occurrences of each Carburant
Carburant_counts = df['Carburant'].value_counts()

plt.figure(figsize=(8, 4))
# Plot the counts using a bar plot
plt.bar(Carburant_counts.index, Carburant_counts.values)
plt.xticks(rotation='vertical')
plt.xlabel('Carburant')
plt.ylabel('Count')
plt.title('Count of each Carburant')
plt.show()

# %%
# Count the occurrences of each Carburant
Carburant_counts = df['Carburant'].value_counts()

plt.figure(figsize=(12, 6))

# Plot the counts using a horizontal bar plot
bars = plt.barh(Carburant_counts.index, Carburant_counts.values)

# Annotate each bar with its count
for bar, count in zip(bars, Carburant_counts.values):
    plt.text(bar.get_width(), bar.get_y() + bar.get_height() / 2, str(count), ha='left', va='center')

plt.xlabel('Count')
plt.ylabel('Carburant')
plt.title('Count of each Carburant')
plt.show()

# %% [markdown]
# ### NEW vs OLD

# %%
mean_prices = df.groupby('etat')['price'].mean()
plt.figure(figsize=(4, 6))
# Plot the counts using a bar plot
plt.bar(mean_prices.index, mean_prices.values)
plt.xlabel('Etat')
plt.ylabel('Mean Price')
plt.title('Mean Price for Etat')
plt.show()

# %%
df.to_csv('latest_global_cars.csv', index=False, encoding='utf-8')
